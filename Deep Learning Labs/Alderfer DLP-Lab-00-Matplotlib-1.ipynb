# %% [markdown]
# # Matplotlib Tutorial

# %% [markdown]
# Credits:  This notebook draws heavily from the [Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook/tree/master/notebooks).  The Python Data Science Handbook is a excellent source of information for all things involving `numpy`, `pandas`, and `matplotlib`.

# %% [markdown]
# How to import `matplotlib`

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Other imports

# %%
import numpy as np

# %% [markdown]
# #### Plotting from an IPython notebook
# Plotting interactively within an IPython notebook can be done with the ``%matplotlib`` command.
# In the IPython notebook, you also have the option of embedding graphics directly in the notebook, with two possible options:
#
# - ``%matplotlib notebook`` will lead to *interactive* plots embedded within the notebook
# - ``%matplotlib inline`` will lead to *static* images of your plot embedded in the notebook

# %% [markdown]
# ### Setting Styles
#
# We will use the ``plt.style`` directive to choose appropriate aesthetic styles for our figures.
# Here we will set the ``classic`` style, which ensures that the plots we create use the classic Matplotlib style:

# %% [markdown]
# Example classic style using the "interactive" mode.  Note that there are user controls at the bottom of the plot for the user to zoom, pan, save, etc.  However, it turns out that this functionality does not work with Google Colab.

# %%
# %matplotlib notebook
fig = plt.figure()
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
plt.style.use('classic')
# Out:
# <img src="data:image/png;base64,..." width="574.4444596620258">

# %% [markdown]
# Example seaborn white grid style using the non interactive mode.  Notice that there are now no controls to interact with the plot.

# %%
# %matplotlib inline
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Saving Figures to File
#
# As a work around to not being able to save figures in Chrome, we can use the `savefig()` command.
# For example, to save the previous figure as a PNG file, you can run this:

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# We now have a file called ``my_figure.png`` in the current working directory:

# %%
! ls
# Out:
# 05-exemplar_hw5.pdf
# 1-2-3building_blocks_actiivity_solution (1).ipynb
# 1-2-3building_blocks_actiivity_solution.ipynb
# 1-300x169.png
# 2-4-1readingfiles.ipynb
# 202112_Wage and Income_ALDE_102588677340.pdf
# 26801_dats_2.2.json
# 26801_ddi_2.5.xml
# 26801_oai_pmh.xml
# 4-4-1readingdata.ipynb
# 4ada6330-f702-4a8b-8b62-1ac75c270834 (1).pdf
# 4ada6330-f702-4a8b-8b62-1ac75c270834.pdf
# 4cf3365e-0f5f-4f32-b37c-e32dc072fd73.html
# 4cf3365e-0f5f-4f32-b37c-e32dc072fd73.pdf
# 7-3-2mongodbdemo.ipynb
# 72bdbf99-da81-4890-8ccd-76c37e3d8d20 (1).pdf
# 72bdbf99-da81-4890-8ccd-76c37e3d8d20.pdf
# 8-1-2db-from-file.ipynb
# 8-1-3_tweets_activity_review.ipynb
# 8-3-1snscrapeexample.ipynb
# 8-4-2facebookscraping.ipynb
# AWS_Lab1.doc
# AWS_Lab1.pdf
# Academic Transcript Alderfer.pdf
# Alderfer_IST_691_HW_02 (1).ipynb
# Alderfer_IST_691_HW_02.ipynb
# Alderfer_Lab2 (1).ipynb
# Alderfer_Question 12 (1).ipynb
# Alderfer_Question 12.ipynb
# Alderfer_Resume (1).pdf
# Alderfer_Resume (2).pdf
# Alderfer_Resume.docx
# Alderfer_Resume.pdf
# Alderfer_Week7ProjectCheckIn.pdf
# Alderfer_Zane (1).ipynb
# Alderfer_Zane (2).ipynb
# Alderfer_Zane HW1.ipynb
# Alderfer_Zane Q11 (1) (1).ipynb
# Alderfer_Zane Q11 (1).ipynb
# Alderfer_Zane Q11.ipynb
# Alderfer_Zane.pdf
# Alderfer_Zane_HW1 (1).ipynb
# Alderfer_Zane_HW1-Copy1.ipynb
# Alderfer_Zane_HW1-Copy2 (1).ipynb
# Alderfer_Zane_HW1-Copy2.ipynb
# Alderfer_Zane_HW1.ipynb
# Alderfer_Zane_HW1.pdf
# Alderfer_Zane_HW5.Rmd
# Alderfer_Zane_HW5.pdf
# Alderfer_Zane_HW6.Rmd
# Alderfer_wk2hw.R
# Alderfer_wk2hw.pdf
# AnalyzeATMBalances.ipynb
# Atom 2.app
# Atom.app
# BayesFactor
# BayesFactor 2
# BayesFactor 3
# BayesFactor 4
# BayesFactor 5
# BayesFactor_0.9.12-4.4 (1).tgz
# BayesFactor_0.9.12-4.4 (2).tgz
# BayesFactor_0.9.12-4.4.tar.gz
# BayesFactor_0.9.12-4.4.tgz
# BaylorEdPsych
# BaylorEdPsych_0.5.tar.gz
# BlueJ-mac-520.dmg
# Case3SalesProducts.csv
# Chapter 2 code recreation pt1 (1) (1).ipynb
# Chapter 2 code recreation pt1 (1).ipynb
# Chapter 2 code recreation pt1.ipynb
# Chris_Snyder_FInal.R
# CoachDescribeExercise.ipynb
# Coaches9.csv
# ContactFinder
# ContactFinder.zip
# Convert_Record_Data_to_Transactions_for_Association_Rule_Mining_in_R (1).Rmd
# Convert_Record_Data_to_Transactions_for_Association_Rule_Mining_in_R.Rmd
# DLP-Lab-00-Matplotlib-1.ipynb
# DLP-Lab-01-Machine-Learning-1.ipynb
# DM_3_3_card2.jpg
# DataReport-ZaneAlderfer (1).pdf
# DataReport-ZaneAlderfer.R
# DataReport-ZaneAlderfer.pdf
# DataScience@Syracuse Advising Packet_pdf.html
# DisclosureStatement.pdf
# Explainer.mp4
# FEDwordsdf.csv
# FINAL IST 707 Project.pdf
# FREDAPIExample.ipynb
# Fall 2023 DataScience@Syracuse Registration Guide_pdf (1).html
# Fall 2023 DataScience@Syracuse Registration Guide_pdf (2).html
# Fall 2023 DataScience@Syracuse Registration Guide_pdf.html
# Fantasy
# Fedwordsfull.csv
# FinalProjectData
# FinalProjectData.zip
# GitHubDesktop-x64.zip
# H-2_Alderfer.pdf
# HW1 (1).ipynb
# HW1.html
# HW1_Alderfer.R
# HW1_Alderfer.pdf
# HW2.ipynb
# HW6--1-.html
# HW6.rmd
# Haley_Lab2.html
# Homework+Assignment+2.pdf
# Homework2.hw2.json
# IMG_2539.HEIC
# IMG_2906.HEIC
# IMG_2906.pdf
# IMG_3147.HEIC
# IMG_3148.HEIC
# IST 652 Quiz 2 Question 9 (1).ipynb
# IST 652 Quiz 2 Question 9.ipynb
# IST 664 lab week 5 quiz.ipynb
# IST 718 Final Project.pdf
# IST-691-HW-01 Zane Alderfer.pdf
# IST-691-HW-01.docx
# IST659_Sample_Project (1).docx
# IST659_Sample_Project.docx
# IST718_ufo_project.ipynb
# IST719_lab2_Alderfer.R
# IST719_lab2_Alderfer.pdf
# IST719hw1.1.pdf
# IST719part1.pdf
# IST_772_Final_Exam (1).docx
# IST_772_Final_Exam.docx
# IST_772_Final_Exam.pdf
# Intro to Data Science - HW 10 - Shiny.html
# Ist 652 quiz 2 question 11 (1).ipynb
# Ist 652 quiz 2 question 11 (2).ipynb
# Ist 652 quiz 2 question 11.ipynb
# Job Offer-Firmwide Regulatory Reporting & Analysis (FRRA) – External Reporting Analyst.pdf
# Kaggle-digit-test-1.csv
# Kaggle-digit-test-sample1000 (1).csv
# Kaggle-digit-test-sample1000.csv
# Kaggle-digit-train-sample-small-1400 (1).csv
# Kaggle-digit-train-sample-small-1400.csv
# Kaggle-digit-train.csv
# Lab 3 part 1 ist 664.ipynb
# Lab2.MorePython2.doc
# Lab3.FilterWords.doc
# Lab4.BigramFreq.MI.doc
# Leave of Absence-.pdf
# Leave of Absence-Alderfer.pdf
# LiveSession10FinalExamReviewJuly2022900PM.pptx
# Martin_Alonso_HW2 (1).docx
# Martin_Alonso_HW2.docx
# MatrixModels
# MatrixModels 2
# MatrixModels_0.5-2.tar.gz
# MatrixModels_0.5-2.tgz
# Meeting_for_HW_explainer_video-20220727_211352-Meeting_Recording_(1).mp4
# Megan_Husted_Project_3.pptx
# MyStudentData.txt
# NLP Investigation Schedule (1).docx
# NLP Investigation Schedule (2).docx
# NLP Investigation Schedule (3).docx
# NLP Investigation Schedule.docx
# NLP investigation UFO dataset.html
# NetflixFillums2021-Search.ipynb
# NetflixFillums2021.ipynb
# New Applied Data Science Advising Packet 2023_pdf (1).html
# New Applied Data Science Advising Packet 2023_pdf.html
# O784423_wk4.R
# O784423_wk4.pdf
# PBIDesktopSetup_x64.exe
# Pay Date 2022-02-28.pdf
# Pay Date 2022-07-01.pdf
# Petition to Faculty AI Secondary Track.pdf
# Petition to Faculty Fillable (1).pdf
# Petition to Faculty Fillable.pdf
# Petition to Faculty Fillable_pdf.html
# Petition to Faculty IST 691.pdf
# PostHocTests.csv
# Poster Critique Marterial Scripts
# Poster Critique Marterial Scripts.zip
# ProjectProposal 1.pdf
# PyCharm.app
# Python-for-Data-Analysis-2nd-Edition.pdf
# RStudio-2023.12.1-402.dmg
# Resume Alderfer.docx
# SQR Report - SUSR001.html
# SSNV Consent-Based SSN Release.pdf
# Screen Shot 2022-09-05 at 7.39.17 PM.png
# SustainableLook.ipynb
# Syracuse_Transcript.pdf
# TE39BBWG.pdf
# TET3UUZP.pdf
# TableauPublic-2022-1-1.dmg
# Team A_Project_2.1.pptx
# Team_A_Final_Presentation Slides 9 19 22.pptx
# Team_A_Final_Project.pdf
# Titanic_Testing_Data.csv
# Titanic_Training_Data (1).csv
# Titanic_Training_Data.csv
# USOnlineEmployeeW2_2023.pdf
# UScensus_abbr_arff.arff
# UScensus_exercise_arff.arff
# Untitled (1).ipynb
# Untitled document.docx
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6 (1).ipynb
# VisualStudioForMacInstaller__19e80735fdb24a05b8ad76c71a550cc0.dmg
# VisualStudioSetup.exe
# Week 1 Breakout Assignment v2.docx
# Week2_Notebooks_Data
# Week2_Notebooks_Data.zip
# Week3_Notebooks_Data
# Week3_Notebooks_Data (1)
# Week3_Notebooks_Data (1).zip
# Week3_Notebooks_Data.zip
# Week_5_Notebooks_Data
# Week_5_Notebooks_Data.zip
# Week_6_Notebooks_Data
# Week_6_Notebooks_Data.zip
# Zane Alderfer AWS Lab#1.pdf
# Zane Alderfer AWS Lab#2.pdf
# Zane Alderfer Microsoft Azure Lab #4 - Part 2.pdf
# Zane Alderfer proof of identification.pdf
# Zane_Alderfer_AzureLab#3 - Part 1.docx
# Zane_Alderfer_Chris_Snyder_Final.pdf
# Zane_Alderfer_Essay1.docx
# Zane_Alderfer_Final.docx
# Zane_Alderfer_Final.pdf
# Zane_Alderfer_FinalProject (1).Rmd
# Zane_Alderfer_FinalProject.Rmd
# Zane_Alderfer_FinalProject.pdf
# Zane_Alderfer_Final_Applied Machine Learning.pdf
# Zane_Alderfer_Final_IST664.pdf
# Zane_Alderfer_Final_Language Processing.pdf
# Zane_Alderfer_Final_Project.ipynb
# Zane_Alderfer_HW1 (1).html
# Zane_Alderfer_HW1.R
# Zane_Alderfer_HW1.docx
# Zane_Alderfer_HW1.html
# Zane_Alderfer_HW1.ipynb
# Zane_Alderfer_HW1.rmd
# Zane_Alderfer_HW10 (1).Rmd
# Zane_Alderfer_HW10.Rmd
# Zane_Alderfer_HW10.pdf
# Zane_Alderfer_HW1_Group94.docx
# Zane_Alderfer_HW1_IST664 (1).ipynb
# Zane_Alderfer_HW1_IST664.docx
# Zane_Alderfer_HW1_IST664.ipynb
# Zane_Alderfer_HW2 (1).docx
# Zane_Alderfer_HW2 (1).html
# Zane_Alderfer_HW2 (1).ipynb
# Zane_Alderfer_HW2 (2).docx
# Zane_Alderfer_HW2.docx
# Zane_Alderfer_HW2.html
# Zane_Alderfer_HW2.log
# Zane_Alderfer_HW2.py
# Zane_Alderfer_HW2.rmd
# Zane_Alderfer_HW2.tex
# Zane_Alderfer_HW3 (1).pdf
# Zane_Alderfer_HW3 - Sheet1.csv
# Zane_Alderfer_HW3.R
# Zane_Alderfer_HW3.docx
# Zane_Alderfer_HW3.html
# Zane_Alderfer_HW3.pdf
# Zane_Alderfer_HW3.py
# Zane_Alderfer_HW3_Group#94.docx
# Zane_Alderfer_HW4.Rmd
# Zane_Alderfer_HW4.docx
# Zane_Alderfer_HW4.html
# Zane_Alderfer_HW4.pdf
# Zane_Alderfer_HW4_2.rmd
# Zane_Alderfer_HW5.docx
# Zane_Alderfer_HW5.html
# Zane_Alderfer_HW5.rmd
# Zane_Alderfer_HW6&7.Rmd
# Zane_Alderfer_HW6&7.docx
# Zane_Alderfer_HW6.Rmd
# Zane_Alderfer_HW6._other.rmd
# Zane_Alderfer_HW6.html
# Zane_Alderfer_HW6.pdf
# Zane_Alderfer_HW7 (1).html
# Zane_Alderfer_HW7.html
# Zane_Alderfer_HW7.pdf
# Zane_Alderfer_HW7.rmd
# Zane_Alderfer_HW8.html
# Zane_Alderfer_HW8.pdf
# Zane_Alderfer_HW8.rmd
# Zane_Alderfer_HW9 (1).html
# Zane_Alderfer_HW9.html
# Zane_Alderfer_HW9.pdf
# Zane_Alderfer_HW9.rmd
# Zane_Alderfer_Homework_1_House_Prices_Team#94 .xlsx
# Zane_Alderfer_IST615_Essay2.pdf
# Zane_Alderfer_IST615_Final
# Zane_Alderfer_IST615_Final 2
# Zane_Alderfer_IST615_Final.zip
# Zane_Alderfer_IST652_Final (1).ipynb
# Zane_Alderfer_IST652_Final.md
# Zane_Alderfer_IST664 - Sheet1.csv
# Zane_Alderfer_IST718_Final_Presentation.pdf
# Zane_Alderfer_IST718_Final_Report.pdf
# Zane_Alderfer_IST718_Lab1.docx
# Zane_Alderfer_IST718_Lab1.py
# Zane_Alderfer_IST718_Lab2.html
# Zane_Alderfer_IST718_Lab2.py
# Zane_Alderfer_IST718_Lab3.html
# Zane_Alderfer_IST718_Lab3.py
# Zane_Alderfer_IST718_UFO_Project.mp4
# Zane_Alderfer_IST718_ufo_project.html
# Zane_Alderfer_IST772_Final.Rmd
# Zane_Alderfer_IST772_Final.pdf
# Zane_Alderfer_Lab3 (1).ipynb
# Zane_Alderfer_Lab3.ipynb
# Zane_Alderfer_Lab4.ipynb
# Zane_Alderfer_Lab5 (1).ipynb
# Zane_Alderfer_Lab5 (2).ipynb
# Zane_Alderfer_Lab5.ipynb
# Zane_Alderfer_Midterm_IST772.pdf
# Zane_Alderfer_NLPInvestigation.pdf
# Zane_Alderfer_PortfolioDraft.pdf
# Zane_Alderfer_Project_3.pptx
# Zane_Alderfer_Project_Final.ipynb
# Zane_Alderfer_Project_Proposal (1).pdf
# Zane_Alderfer_Project_Proposal (2).pdf
# Zane_Alderfer_Project_Proposal.pdf
# Zane_Alderfer_RecentWork.html
# Zane_Alderfer_RecentWork.ipynb
# Zane_Alderfer_RecentWork2
# Zane_Alderfer_RecentWork2 (1)
# Zane_Alderfer_Recent_Work.ipynb
# Zane_Alderfer_Recent_Work.md
# Zane_Alderfer_Resume_final.pdf
# Zane_Alderfer_Team_Peer_Review.docx
# Zane_Alderfer_lab2.html
# Zane_Alderfer_lab2.py
# Zip_zhvi_uc_sfr_month.csv
# adp_merged_7_17.csv
# alderfer_zane (1).txt
# archive
# archive (1).zip
# archive (2).zip
# archive 2
# archive.zip
# art-1.csv
# atom-mac (1).zip
# atom-mac.zip
# attachments
# attachments.zip
# bankdata_csv_all.csv
# bball_mm2.txt
# bball_mm2.zip
# benjamin_heindl_lab2 1.pdf
# breakout 3 combined pdfs (1).pdf
# breakout 3 combined pdfs.pdf
# breakoutweek3.R
# cheriton
# cheriton (1)
# climatetweets_useforlecture_25k.csv
# clustering pt 1 ist 707.R
# coaches.csv
# coaches_modify.xlsx
# combined_data.csv
# combined_data_NB.csv
# contactfinder (1).zip
# corp-prod.s3.us-west-2.amazonaws.com_uploads_2ce40ecf-903e-48d6-b407-d7830b6f4601_4eb82acb-8408-48a7-9e62-b3f7a0e33eb0_crimeandpunishment.txt_AWSAccessKeyId=AKIAI3SC6Y7T66PAO2FA&Expires=1688971742&Signature=g0zuVxogK9GR2qJ%2FJbGW5.txt
# corp-prod.s3.us-west-2.amazonaws.com_uploads_3b7c11e2-312e-40f8-b76f-e55813394305_17819ae3-1655-4274-9f38-cea89d260b35_labweek3.processtext.examples.txt_AWSAccessKeyId=AKIAI3SC6Y7T66PAO2FA&Expires=1688971766&Signature=MrxDr%2B5ZcL.txt
# corp-prod.s3.us-west-2.amazonaws.com_uploads_43f75f28-e95b-49bc-a61e-e3444598e119_a124d5b1-bea9-45e3-9b76-3dada2c6ce45_labweek3.regexp.examples.txt_AWSAccessKeyId=AKIAI3SC6Y7T66PAO2FA&Expires=1688971952&Signature=1UN7FW5P0Vlw5fyBu.txt
# corp-prod.s3.us-west-2.amazonaws.com_uploads_7998a116-2e12-416d-8c7b-3b954d72e6f0_0282d5db-34d5-467f-b5fe-49d8a9aabbb6_labweek4.postags.txt_AWSAccessKeyId=AKIAI3SC6Y7T66PAO2FA&Expires=1688972178&Signature=Bm2BH3MZOdG2O.txt
# corp-prod.s3.us-west-2.amazonaws.com_uploads_c6f0aef8-c64d-41b3-a8a6-70acabbd2590_c173d6de-003a-476c-8e1b-424da6fe4efc_desert.txt_AWSAccessKeyId=AKIAI3SC6Y7T66PAO2FA&Expires=1688971784&Signature=jaIcOEEZC3D-1.txt
# cover letter_Zane_Alderfer_Affirm.pdf
# cover letter_Zane_Alderfer_BAH.pdf
# cover letter_Zane_Alderfer_Brunswick.pdf
# cover letter_Zane_Alderfer_BureauofFiscalPolicy.pdf
# cover letter_Zane_Alderfer_Cardinal Health.pdf
# cover letter_Zane_Alderfer_JPMC Data Architect.pdf
# cover letter_Zane_Alderfer_JPMC RIsk Management.pdf
# cover letter_Zane_Alderfer_JPMC Risk Reporting.pdf
# cover letter_Zane_Alderfer_JPMorgan (1).pdf
# cover letter_Zane_Alderfer_JPMorgan (2).pdf
# cover letter_Zane_Alderfer_JPMorgan.pdf
# cover letter_Zane_Alderfer_Microsoft.pdf
# cover letter_Zane_Alderfer_Sedona.pdf
# cover letter_Zane_Alderfer_SlingshotAerospace.pdf
# cover letter_Zane_Alderfer_TDBank.pdf
# d67dc069-de93-40b8-9eac-8aed288c9ca8.pdf
# data-storyteller.csv
# data_donors_updated (1).xlsx
# data_donors_updated.ods
# data_donors_updated.xlsx
# data_donors_updatedv2.csv
# data_storyteller-1.csv
# db_fn (1).py
# db_fn.py
# df09f638-1250-49db-a0cc-845fb3a9d38c.html
# df09f638-1250-49db-a0cc-845fb3a9d38c.pdf
# direct deposit.pdf
# doc_6500245c-f6b2-4802-8757-0b4003e9f773.html
# dodgers.csv
# donors_data (1).csv
# donors_data.csv
# donors_data.xlsx
# ebc1b48f-c01d-4087-92fd-7c9c0cc5216a (1).pdf
# ebc1b48f-c01d-4087-92fd-7c9c0cc5216a (2).pdf
# ebc1b48f-c01d-4087-92fd-7c9c0cc5216a.pdf
# energy_dataset.csv
# energy_dataset.csv.zip
# energy_weather_data.csv
# energydataupdated.csv
# eur.pop.rev.csv
# fantasy_full.csv
# fantasy_merged_7_17.csv
# fashion-mnist_test.csv
# fashion-mnist_test.csv.zip
# fashion-mnist_train.csv
# fashion-mnist_train.csv.zip
# fedPapers85 (1).csv
# fedPapers85.csv
# fig_advert_promo_dodgers_eda_day_of_week_Python.pdf
# final_project_join_SQL.sql
# form-petition-to-faculty.pdf
# fridakahlo
# fridakahlo 2
# fridakahlo.zip
# googlechrome.dmg
# groceries.Rmd
# groceries.csv
# heart_statlog_cleveland_hungary_final.csv
# homework2.docx
# hot-dog-contest-winners.csv
# hurricane_analysis_starting.zip
# ideaIC-2023.2.2.dmg
# ideaIC-2023.2.2.exe
# ideaIU-2023.2.2.dmg
# invite.ics
# ist 646 week 6 lab example 1.ipynb
# ist 664 lab 3 part 2.ipynb
# ist 707 final project prep.R
# ist719_lab1_Alderfer.R
# ist719_lab1_Alderfer.pdf
# ist719hw1.2.pdf
# ist719hw1.3.pdf
# ist719hw1.4.pdf
# ist719hw1.5.pdf
# ist719hw1.6.pdf
# ist719hw1.7.pdf
# ist719hw3.1.pdf
# ist719hw3.2.pdf
# ist719hw3.3.pdf
# ist719hw3.4.pdf
# ist719hw4.1.pdf
# ist719hw4.10.pdf
# ist719hw4.11.pdf
# ist719hw4.2.pdf
# ist719hw4.3.pdf
# ist719hw4.4.pdf
# ist719hw4.5.pdf
# ist719hw4.6.pdf
# ist719hw4.7.pdf
# ist719hw4.8.pdf
# ist719hw4.9.pdf
# ist719lab3.1.pdf
# ist719lab3.2.pdf
# ist719lab3.4.pdf
# ist719lab3.5.pdf
# ist719lab3_Alderfer.pdf
# ist719lab4.1.pdf
# ist719wk5.1.pdf
# jdk-21.jdk
# jdk-21.jdk 2
# jdk-21_macos-aarch64_bin (1).tar.gz
# jdk-21_macos-aarch64_bin.dmg
# jdk-21_macos-aarch64_bin.tar.gz
# jdk-21_macos-x64_bin.dmg
# joined_file.csv
# learnjava5e-master
# learnjava5e-master.zip
# lease.pdf
# master_ufo_data.csv
# miller_chapter2_with_mods.ipynb
# misc.ipynb
# mongodb-compass-1.39.3-darwin-x64.dmg
# mongosh-1.10.6-darwin-x64
# mongosh-1.10.6-darwin-x64.zip
# my_figure.png
# npp.8.3.3.Installer.x64.exe
# pay_statements
# pay_statements (1).zip
# pay_statements (2).zip
# pay_statements.zip
# petition to return.pdf
# pollution-sightings geographic .ipynb
# pollution_us_2000_2016.csv
# price_of_gasoline.xl.csv
# processtextfile.py
# pycharm-professional-2021.3.2.dmg
# pycharm-professional-2023.1.2.dmg
# rcodecomplete.r
# retail.csv
# sales (1).csv
# sales (2).csv
# sales.csv
# scatter.pdf
# schoolvax.xlsx
# scm651_business_analytics_homework_3 (1).doc
# scm651_business_analytics_homework_3.doc
# scm651_business_analytics_homework_4 (1).doc
# scm651_business_analytics_homework_4.doc
# scm651_homework_3_book_prices (1).xlsx
# scm651_homework_3_book_prices (2).xlsx
# scm651_homework_3_book_prices.xlsx
# scm651_homework_4_universal_bank (1) (1).xlsx
# scm651_homework_4_universal_bank (1).xlsx
# scm651_homework_4_universal_bank.xlsx
# script.py
# smart.english.stop
# state_satscores_2004.tsv
# state_satscores_2004.txt
# stores_averages.xlsx
# subjclueslen1-hltemnlp05.tff.zip
# subjectivity.txt
# titanic-e1071-NB.Rmd
# titanic-multi-models.Rmd
# titanic-new-nb.csv
# ubuntu-22.04.3-live-server-arm64.iso
# ufo_project.ipynb
# untitled folder
# weather_features.csv
# weather_features.csv.zip
# weather_nominal_arff.arff
# weatherdataupdated.csv
# week 2 breakout combined plots (1).pdf
# week 2 breakout combined plots.pdf
# week1thinkpairshare.docx
# week2binomialexercise.docx
# week2randombinomial.docx
# week3simulatedpopulation.docx
# week4practiceexam.docx
# week4practiceexam_Summer2023.docx
# week9practiceexam.docx
# weka-3-8-6-azul-zulu-osx.dmg
# wine.txt
# zoo.arff
# zoo.csv

# %% [markdown]
# ## Two Interfaces for the Price of One
#
# A potentially confusing feature of Matplotlib is its dual interfaces: a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface. We'll quickly highlight the differences between the two here.

# %% [markdown]
# #### MATLAB-style Interface
#
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact.
# The MATLAB-style tools are contained in the pyplot (``plt``) interface.
# For example, the following code will probably look quite familiar to MATLAB users.  Also note that we are using the ``subplot`` call as opposed to the ``subplots`` call which will be used for the object oriented style.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 2, 1) # (rows, columns, index)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x));

# create the third panel and set current axis
plt.subplot(2, 2, 3)
plt.plot(x, np.cos(x)+2);


# create the fourth panel and set current axis
plt.subplot(2, 2, 4)
plt.plot(x, np.sin(x)+2);

# %% [markdown]
# It is important to note that this interface is *stateful*: it keeps track of the "current" figure and axes, which are where all ``plt`` commands are applied.
#
# You can get a reference to these using the ``plt.gcf()`` (get current figure) and ``plt.gca()`` (get current axes) routines.

# %% [markdown]
# #### Object-oriented interface
#
# The object-oriented interface is available when you want more control over your figure.  Rather than depending on some notion of an "active" figure or axes, the plotting functions are *methods* of explicit ``Figure`` and ``Axes`` objects.  The following is a repeat of the above using the object oriented style.

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Add some space around the plots
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=1.1,
                    wspace=0.4,
                    hspace=0.4)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# For more simple plots, the choice of which style to use is largely a matter of preference, but the object-oriented approach can become a necessity as plots become more complicated.
#
# In most cases, the difference is as small as switching ``plt.plot()`` to ``ax.plot()``, but there are a few gotchas that we will highlight as they come up in the following sections.

# %% [markdown]
# # Simple Line Plots

# %% [markdown]
# Perhaps the simplest of all plots is the visualization of a single function $y = f(x)$.
# Here we will take a first look at creating a simple plot of this type.  For all Matplotlib plots, we start by creating a figure and an axes.
# In their simplest form, a figure and axes can be created as follows:

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* is an abstract container that contains the axes.
#
# Once we have created the axes, we can use the ``ax.plot`` function to plot some data. Let's start with a simple sinusoid:

# %%
# Object oriented style
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
ax.plot(x, np.cos(x));

# %% [markdown]
# Alternatively, we can use the matlab style interface:

# %%
# matlab style
plt.plot(x, np.sin(x));

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the ``plot`` function multiple times:

# %%
# matlab style
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# That's all there is to plotting simple functions in Matplotlib!
# We'll now dive into some more details about how to control the appearance of the axes and lines.

# %% [markdown]
# ## Adjusting the Plot: Line Colors and Styles

# %% [markdown]
# The first adjustment you might wish to make to a plot is to control the line colors and styles.
# The ``plt.plot()`` function takes additional arguments that can be used to specify these.
# To adjust the color, you can use the ``color`` keyword, which accepts a string argument representing virtually any imaginable color.
# The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color = 'blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color = 'g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color = '0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color = '#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color = (1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color = 'chartreuse'); # all HTML color names supported

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines.
#
# Similarly, the line style can be adjusted using the ``linestyle`` keyword:

# %%
plt.plot(x, x + 0, linestyle = 'solid')
plt.plot(x, x + 1, linestyle = 'dashed')
plt.plot(x, x + 2, linestyle = 'dashdot')
plt.plot(x, x + 3, linestyle = 'dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle = '-')  # solid
plt.plot(x, x + 5, linestyle = '--') # dashed
plt.plot(x, x + 6, linestyle = '-.') # dashdot
plt.plot(x, x + 7, linestyle = ':');  # dotted

# %% [markdown]
# If you would like to be extremely terse, these ``linestyle`` and ``color`` codes can be combined into a single non-keyword argument to the ``plt.plot()`` function:

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK) color systems, commonly used for digital color graphics.
#
# There are many other keyword arguments that can be used to fine-tune the appearance of the plot; for more details, I'd suggest viewing the docstring of the ``plt.plot()`` function using IPython's help tools (See [Help and Documentation in IPython](01.01-Help-And-Documentation.ipynb)).

# %% [markdown]
# ## Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control.
# The most basic way to adjust axis limits is to use the ``plt.xlim()`` and ``plt.ylim()`` methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# If for some reason you'd like either axis to be displayed in reverse, you can simply reverse the order of the arguments:

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is ``plt.axis()`` (note here the potential confusion between 'axes' with an 'e' , and 'axis' with an 'i').
# The ``plt.axis()`` method allows you to set the ``x`` and ``y`` limits with a single call, by passing a list which specifies ``[xmin, xmax, ymin, ymax]``:

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# The ``plt.axis()`` method goes even beyond this, allowing you to do things like automatically tighten the bounds around the current plot:

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %% [markdown]
# It allows even higher-level specifications, such as ensuring an equal aspect ratio so that on your screen, one unit in ``x`` is equal to one unit in ``y``:

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# For more information on axis limits and the other capabilities of the ``plt.axis`` method, refer to the ``plt.axis`` docstring.

# %% [markdown]
# ## Labeling Plots
#
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)');

# %% [markdown]
# The position, size, and style of these labels can be adjusted using optional arguments to the function.
# For more information, see the Matplotlib documentation and the docstrings of each of these functions.

# %% [markdown]
# When multiple lines are being shown within a single axis, it can be useful to create a plot legend that labels each line type.
# Again, Matplotlib has a built-in way of quickly creating such a legend.
# It is done via the (you guessed it) ``plt.legend()`` method.
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the ``label`` keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label = 'sin(x)')
plt.plot(x, np.cos(x), ':b', label = 'cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# As you can see, the ``plt.legend()`` function keeps track of the line style and color, and matches these with the correct label.
# More information on specifying and formatting plot legends can be found in the ``plt.legend`` docstring.

# %% [markdown]
# ## Matlab style to object oriented translations
#
# While most ``plt`` functions translate directly to ``ax`` methods (such as ``plt.plot()`` → ``ax.plot()``, ``plt.legend()`` → ``ax.legend()``, etc.), this is not the case for all commands.
# In particular, functions to set limits, labels, and titles are slightly modified.
# For transitioning between MATLAB-style functions and object-oriented methods, make the following changes:
#
# - ``plt.xlabel()``  → ``ax.set_xlabel()``
# - ``plt.ylabel()`` → ``ax.set_ylabel()``
# - ``plt.xlim()``  → ``ax.set_xlim()``
# - ``plt.ylim()`` → ``ax.set_ylim()``
# - ``plt.title()`` → ``ax.set_title()``

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ``ax.set()`` method to set all these properties at once.

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim = (-2, 2),
       xlabel = 'x', ylabel = 'sin(x)',
       title='A Simple Plot');

# %% [markdown]
# # Simple Scatter Plots

# %% [markdown]
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot.
# Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.
# We’ll start by setting up the notebook for plotting and importing the functions we will use:

# %% [markdown]
# ## Scatter Plots with ``plt.plot``
#
# In the previous section we looked at ``plt.plot``/``ax.plot`` to produce line plots.
# It turns out that this same function can produce scatter plots as well:

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color = 'black');

# %% [markdown]
# The third argument in the function call is a character that represents the type of symbol used for the plotting. Just as you can specify options such as ``'-'``, ``'--'`` to control the line style, the marker style has its own set of short string codes. The full list of available symbols can be seen in the documentation of ``plt.plot``, or in Matplotlib's online documentation. Most of the possibilities are fairly intuitive, and we'll show a number of the more common ones here:

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label = "marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# For even more possibilities, these character codes can be used together with line and color codes to plot points along with a line connecting them:

# %%
plt.plot(x, y, '-ok');

# %% [markdown]
# Additional keyword arguments to ``plt.plot`` specify a wide range of properties of the lines and markers:

# %%
plt.plot(x, y, '-p', color = 'gray',
         markersize = 15, linewidth = 4,
         markerfacecolor = 'white',
         markeredgecolor = 'gray',
         markeredgewidth = 2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# This type of flexibility in the ``plt.plot`` function allows for a wide variety of possible visualization options.
# For a full description of the options available, refer to the ``plt.plot`` documentation.

# %% [markdown]
# ## Scatter Plots with ``plt.scatter``
#
# A second, more powerful method of creating scatter plots is the ``plt.scatter`` function, which can be used very similarly to the ``plt.plot`` function:

# %%
plt.scatter(x, y, marker = 'o');

# %% [markdown]
# The primary difference of ``plt.scatter`` from ``plt.plot`` is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.
#
# Let's show this by creating a random scatter plot with points of many colors and sizes.
# In order to better see the overlapping results, we'll also use the ``alpha`` keyword to adjust the transparency level:

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c = colors, s = sizes, alpha = 0.3,
            cmap = 'viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# Notice that the color argument is automatically mapped to a color scale (shown here by the ``colorbar()`` command), and that the size argument is given in pixels.
# In this way, the color and size of points can be used to convey information in the visualization, in order to visualize multidimensional data.
#
# For example, we might use the Iris data from Scikit-Learn, where each sample is one of three types of flowers that has had the size of its petals and sepals carefully measured:

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

# s = size = petal width, c = color = species
plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target,
            cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
plt.title("Iris Data Set\nPoint size = petal width\nColor = Species")
# Out:
# /Users/zanealderfer/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Text(0.5, 1.0, 'Iris Data Set\nPoint size = petal width\nColor = Species')

# %% [markdown]
# We can see that this scatter plot has given us the ability to simultaneously explore four different dimensions of the data:
# the (x, y) location of each point corresponds to the sepal length and width, the size of the point is related to the petal width, and the color is related to the particular species of flower.
# Multicolor and multifeature scatter plots like this can be useful for both exploration and presentation of data.

# %% [markdown]
# ## ``plot`` Versus ``scatter``: A Note on Efficiency
#
# It turns out that ``plt.plot`` can be noticeably more efficient than ``plt.scatter``.  The reason is that ``plt.scatter`` has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually.

# %% [markdown]
# # Histograms, Binnings, and Density

# %% [markdown]
# A simple histogram can be a great first step in understanding a dataset.

# %%
data = np.random.randn(1000)

# %%
plt.hist(data);

# %% [markdown]
# The ``hist()`` function has many options to tune both the calculation and the display;
# here's an example of a more customized histogram:

# %%
plt.hist(data, bins = 30, density = True, alpha = 0.5,
         histtype = 'stepfilled', color = 'steelblue',
         edgecolor = 'none');

# %% [markdown]
# The `plt.hist` docstring has more information on other customization options available.
# I find this combination of `histtype = 'stepfilled'` along with some transparency `alpha` to be very useful when comparing histograms of several distributions:

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype = 'stepfilled', alpha = 0.3, density = True, bins = 40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# If you would like to simply compute the histogram (that is, count the number of points in a given bin) and not display it, the ``np.histogram()`` function is available:

# %%
counts, bin_edges = np.histogram(data, bins = 5)
print(counts)
# Out:
# [ 15 153 517 282  33]
